# %%
import pandas as pd
import os
import requests
import datetime as dt
from config import noaa_token as token

# %%
#variables
base = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/'
header = {'token':token,
          'Content-Type':'application/json'}

dataset = {'datasetid':'GHCND'}
location = {'locationid':'CLIM:102'}
datatypes = {'datatypeid':'ID'}

payload = {'locationid':'CLIM:102',
          'limit':'1000'}

query_list = ['precipitation','snowfall','ice','water']
avoid_list = ['average','percentile','probability','multiday','mean']

# %%
#get count
def get_c(json):
    return json['metadata']['resultset']['count']

#take end point as a string and payload as a dictionary
def gather(endpt,load):
    initial = requests.get(base+endpt,headers=header,params=load).json()
    count = get_c(initial)
    json = initial['results']
    offset = 1000
    while offset < count:
        load['offset'] = offset
        json += requests.get(base+endpt,headers=header,params=load).json()['results']
        offset += 1000
    return pd.DataFrame(json)

#returns subset of df where maxdate is in December 2019
def recent(df):
    return df[df['maxdate'].str.startswith('2019-12')]

# %%
dt_df = gather('datatypes',payload)
dt_df['name'] = dt_df['name'].str.lower()
dt_df
# Out:
#          mindate     maxdate  \
# 0     1994-03-19  1996-05-28
# 1     1965-01-01  2005-12-31
# 2     1994-02-01  1996-05-28
# 3     1965-01-01  2005-12-31
# 4     1991-06-05  2019-12-20
# ...          ...         ...
# 1126  1996-07-08  2005-09-09
# 1127  1996-10-21  2002-02-04
# 1128  1996-07-01  2005-12-31
# 1129  2010-01-01  2010-12-31
# 1130  2010-01-01  2010-12-31
#
#                                                    name  datacoverage  \
# 0     average cloudiness midnight to midnight from 3...          1.00
# 1     average cloudiness midnight to midnight from m...          1.00
# 2     average cloudiness sunrise to sunset from 30-s...          1.00
# 3     average cloudiness sunrise to sunset from manu...          1.00
# 4                                             base data          0.95
# ...                                                 ...           ...
# 1126      ash, dust, sand, or other blowing obstruction          1.00
# 1127                               snow or ice crystals          1.00
# 1128                                rain or snow shower          1.00
# 1129  long-term average year-to-date precipitation t...          1.00
# 1130     long-term average year-to-date snowfall totals          1.00
#
#                    id
# 0                ACMC
# 1                ACMH
# 2                ACSC
# 3                ACSH
# 4                 ALL
# ...               ...
# 1126             WV07
# 1127             WV18
# 1128             WV20
# 1129  YTD-PRCP-NORMAL
# 1130  YTD-SNOW-NORMAL
#
# [1131 rows x 5 columns]

# %%
recent(dt_df)
# Out:
#          mindate     maxdate  \
# 4     1991-06-05  2019-12-20
# 234   2011-03-08  2019-12-18
# 236   1832-05-11  2019-12-18
# 239   1994-05-20  2019-12-18
# 357   2011-03-08  2019-12-18
# ...          ...         ...
# 1107  1851-04-13  2019-12-15
# 1108  1890-03-28  2019-12-15
# 1110  1851-04-11  2019-12-15
# 1111  1852-02-12  2019-12-14
# 1112  1886-03-20  2019-12-09
#
#                                                    name  datacoverage    id
# 4                                             base data          0.95   ALL
# 234   digital accumulation array(one hour precipitat...          0.95   DAA
# 236   number of days included in the multiday precip...          1.00  DAPR
# 239                    digital hybrid scan reflectivity          0.95   DHR
# 357         one hour precipitation difference = daa-n1p          0.95   DOD
# ...                                                 ...           ...   ...
# 1107                      hail (may include small hail)          1.00  WT05
# 1108                                     glaze or rime           1.00  WT06
# 1110                                     smoke or haze           1.00  WT08
# 1111                           blowing or drifting snow          1.00  WT09
# 1112             tornado, waterspout, or funnel cloud"           1.00  WT10
#
# [104 rows x 5 columns]

# %%
stations_df = gather('stations',payload)
stations_df
# Out:
#       elevation     mindate     maxdate  latitude  \
# 0         228.6  1941-04-01  2008-06-01  42.48110
# 1         164.0  1935-07-01  2015-11-01  40.88210
# 2         167.6  1935-07-01  2015-11-01  41.42550
# 3         167.6  1931-01-01  2009-09-01  41.09944
# 4         173.1  1985-06-01  2015-11-01  41.51800
# ...         ...         ...         ...       ...
# 6340      185.9  2005-01-01  2019-12-19  47.74722
# 6341      204.8  2005-01-01  2019-12-19  43.15611
# 6342      417.6  2005-01-01  2019-12-19  46.44667
# 6343      393.8  2005-01-01  2019-12-19  41.70000
# 6344      367.0  2005-01-01  2019-12-19  46.54750
#
#                                     name  datacoverage           id  \
# 0                         ANTIOCH, IL US        0.9542  COOP:110203
# 1                GLADSTONE DAM 18, IL US        0.9741  COOP:113455
# 2            ILLINOIS CITY DAM 16, IL US        0.9772  COOP:114355
# 3                      KEITHSBURG, IL US        0.9598  COOP:114655
# 4     ROCK ISLAND LOCK AND DAM 15, IL US        0.9479  COOP:117391
# ...                                  ...           ...          ...
# 6340                 GRAND MARAIS, MN US        1.0000   WBAN:94992
# 6341             BOSCOBEL AIRPORT, WI US        1.0000   WBAN:94994
# 6342     WADENA MUNICIPAL AIRPORT, MN US        1.0000   WBAN:94997
# 6343    AUDUBON MUNICIPAL AIRPORT, IA US        1.0000   WBAN:94998
# 6344     AITKIN MUNICIPAL AIRPORT, MN US        1.0000   WBAN:94999
#
#      elevationUnit  longitude
# 0           METERS  -88.09940
# 1           METERS  -91.02340
# 2           METERS  -91.00940
# 3           METERS  -90.93944
# 4           METERS  -90.56470
# ...            ...        ...
# 6340        METERS  -90.34444
# 6341        METERS  -90.67750
# 6342        METERS  -95.21167
# 6343        METERS  -94.91667
# 6344        METERS  -93.67667
#
# [6345 rows x 9 columns]

# %%
recent(stations_df)
# Out:
#       elevation     mindate     maxdate   latitude  \
# 1611      335.0  1978-12-01  2019-12-16  48.633300
# 1615      383.4  1998-06-17  2019-12-17  43.267291
# 1616      341.4  2018-05-26  2019-12-17  43.401739
# 1617      329.2  2018-09-19  2019-12-18  43.140900
# 1621      295.4  2018-03-23  2019-12-18  40.734480
# ...         ...         ...         ...        ...
# 6340      185.9  2005-01-01  2019-12-19  47.747220
# 6341      204.8  2005-01-01  2019-12-19  43.156110
# 6342      417.6  2005-01-01  2019-12-19  46.446670
# 6343      393.8  2005-01-01  2019-12-19  41.700000
# 6344      367.0  2005-01-01  2019-12-19  46.547500
#
#                                   name  datacoverage                 id  \
# 1611                    BARWICK, MN US        1.0000  GHCND:CA006020559
# 1615             WAUKON 0.5 ESE, IA US        0.9988  GHCND:US1IAAL0004
# 1616             LANSING 4.1 NW, IA US        0.9442  GHCND:US1IAAL0005
# 1617           POSTVILLE 5.5 NE, IA US        1.0000  GHCND:US1IAAL0006
# 1621         CENTERVILLE 0.3 NE, IA US        0.7830  GHCND:US1IAAP0007
# ...                                ...           ...                ...
# 6340               GRAND MARAIS, MN US        1.0000         WBAN:94992
# 6341           BOSCOBEL AIRPORT, WI US        1.0000         WBAN:94994
# 6342   WADENA MUNICIPAL AIRPORT, MN US        1.0000         WBAN:94997
# 6343  AUDUBON MUNICIPAL AIRPORT, IA US        1.0000         WBAN:94998
# 6344   AITKIN MUNICIPAL AIRPORT, MN US        1.0000         WBAN:94999
#
#      elevationUnit  longitude
# 1611        METERS -93.966700
# 1615        METERS -91.466922
# 1616        METERS -91.285070
# 1617        METERS -91.492600
# 1621        METERS -92.870150
# ...            ...        ...
# 6340        METERS -90.344440
# 6341        METERS -90.677500
# 6342        METERS -95.211670
# 6343        METERS -94.916670
# 6344        METERS -93.676670
#
# [1951 rows x 9 columns]

# %%
v_df = pd.DataFrame()
for q in query_list:
    e_df = dt_df[dt_df['name'].str.contains(q)]
    for a in avoid_list:
        e_df = e_df[~(e_df['name'].str.contains(a))]
    v_df = v_df.append(e_df)
v_df.reset_index()
# Out:
#     index     mindate     maxdate  \
# 0     234  2011-03-08  2019-12-18
# 1     357  2011-03-08  2019-12-18
# 2     358  1994-06-17  2019-12-18
# 3     359  1888-12-01  2015-11-01
# 4     361  2011-03-08  2019-12-18
# 5     362  2011-03-08  2019-12-18
# 6     363  1994-06-17  2019-12-18
# 7     364  2011-03-08  2019-12-18
# 8     939  1994-06-17  2019-12-18
# 9     956  1994-06-17  2019-12-18
# 10    985  1994-06-17  2019-12-18
# 11    988  2011-03-08  2019-12-18
# 12    990  2011-03-08  2019-12-18
# 13    991  1996-01-01  2014-01-01
# 14    992  1970-05-12  2014-01-01
# 15   1074  1994-05-20  2019-12-18
# 16   1121  1992-11-01  2013-03-31
# 17   1102  1998-06-01  2019-12-18
# 18   1091  1926-03-17  2019-10-24
# 19   1103  1851-05-19  2019-12-15
# 20   1106  1852-02-20  2019-12-15
# 21   1120  1851-04-13  2019-04-13
# 22   1123  1979-01-01  2017-03-26
# 23   1124  1996-07-01  2005-12-24
# 24   1127  1996-10-21  2002-02-04
# 25   1091  1926-03-17  2019-10-24
# 26   1101  1952-07-01  2019-12-18
# 27   1102  1998-06-01  2019-12-18
# 28   1112  1886-03-20  2019-12-09
#
#                                                  name  datacoverage    id
# 0   digital accumulation array(one hour precipitat...          0.95   DAA
# 1         one hour precipitation difference = daa-n1p          0.95   DOD
# 2                         digital precipitation array          0.95   DPA
# 3        departure from normal monthly precipitation.          1.00  DPNP
# 4                    instantaneous precipitation rate          0.95   DPR
# 5      storm total precipitation difference = dta-dsp          0.95   DSD
# 6                   digital storm total precipitation          0.95   DSP
# 7   digital storm total accumulation(storm total p...          0.95   DTA
# 8                        one hour precipitation total          0.95   N1P
# 9                      three hour precipitation total          0.95   N3P
# 10                          storm total precipitation          0.95   NTP
# 11  one hour accumulation(one hour precipitation t...          0.95   OHA
# 12  storm total accumulation(storm total precipita...          0.95   PTA
# 13                                      precipitation          0.25  QGAG
# 14                                      precipitation          0.25  QPCP
# 15                    supplemental precipitation data          0.95   SPD
# 16                   unknown source of precipitation           1.00  WT19
# 17                       water equivalent of snowfall          1.00  WESF
# 18                          thickness of ice on water          1.00  THIC
# 19  fog, ice fog, or freezing fog (may include hea...          1.00  WT01
# 20  ice pellets, sleet, snow pellets, or small hail"           1.00  WT04
# 21   snow, snow pellets, snow grains, or ice crystals          1.00  WT18
# 22                            ice fog or freezing fog          1.00  WT22
# 23  fog, ice fog, or freezing fog (may include hea...          1.00  WV01
# 24                               snow or ice crystals          1.00  WV18
# 25                          thickness of ice on water          1.00  THIC
# 26             water equivalent of snow on the ground          1.00  WESD
# 27                       water equivalent of snowfall          1.00  WESF
# 28             tornado, waterspout, or funnel cloud"           1.00  WT10
