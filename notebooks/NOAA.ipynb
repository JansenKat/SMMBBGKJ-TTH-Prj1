# %%
import pandas as pd
import os
import requests
import datetime as dt
from config import noaa_token as token

# %%
#variables
base = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/'
header = {'token':token,
          'Content-Type':'application/json'}

dataset = {'datasetid':'GHCND'}
location = {'locationid':'CLIM:102'}
datatypes = {'datatypeid':'ID'}

payload = {'locationid':'CLIM:102',
          'limit':'1000'}

query_list = ['precipitation','snow','ice','water']
avoid_list = ['average','percentile','probability','multiday','mean']

# %%
#get count
def get_c(json):
    return json['metadata']['resultset']['count']

#take end point as a string and payload as a dictionary
def gather(endpt,load):
    initial = requests.get(base+endpt,headers=header,params=load).json()
    count = get_c(initial)
    json = initial['results']
    offset = 1000
    while offset < count:
        load['offset'] = offset
        json += requests.get(base+endpt,headers=header,params=load).json()['results']
        offset += 1000
    return pd.DataFrame(json)

#returns subset of df where maxdate is in December 2019
def recent(df):
    return df[df['maxdate'].str.startswith('2019-12')]

# %%
dt_df = gather('datatypes',payload)
dt_df['name'] = dt_df['name'].str.lower()
dt_df
# Out:
#          mindate     maxdate  \
# 0     1994-03-19  1996-05-28
# 1     1965-01-01  2005-12-31
# 2     1994-02-01  1996-05-28
# 3     1965-01-01  2005-12-31
# 4     1991-06-05  2020-01-08
# ...          ...         ...
# 1126  1996-07-08  2005-09-09
# 1127  1996-10-21  2002-02-04
# 1128  1996-07-01  2005-12-31
# 1129  2010-01-01  2010-12-31
# 1130  2010-01-01  2010-12-31
#
#                                                    name  datacoverage  \
# 0     average cloudiness midnight to midnight from 3...          1.00
# 1     average cloudiness midnight to midnight from m...          1.00
# 2     average cloudiness sunrise to sunset from 30-s...          1.00
# 3     average cloudiness sunrise to sunset from manu...          1.00
# 4                                             base data          0.95
# ...                                                 ...           ...
# 1126      ash, dust, sand, or other blowing obstruction          1.00
# 1127                               snow or ice crystals          1.00
# 1128                                rain or snow shower          1.00
# 1129  long-term average year-to-date precipitation t...          1.00
# 1130     long-term average year-to-date snowfall totals          1.00
#
#                    id
# 0                ACMC
# 1                ACMH
# 2                ACSC
# 3                ACSH
# 4                 ALL
# ...               ...
# 1126             WV07
# 1127             WV18
# 1128             WV20
# 1129  YTD-PRCP-NORMAL
# 1130  YTD-SNOW-NORMAL
#
# [1131 rows x 5 columns]

# %%
recent(dt_df)
# Out:
#          mindate     maxdate  \
# 1001  1982-01-01  2019-12-31
# 1007  1982-01-01  2019-12-31
# 1080  1982-01-01  2019-12-31
# 1085  1982-01-01  2019-12-31
# 1109  1891-12-21  2019-12-31
# 1112  1886-03-20  2019-12-09
# 1113  1851-04-03  2019-12-31
#
#                                                    name  datacoverage    id
# 1001  minimum soil temperature with bare ground cove...           1.0  SN32
# 1007  minimum soil temperature with sod cover at 10 ...           1.0  SN52
# 1080  maximum soil temperature with bare ground cove...           1.0  SX32
# 1085  maximum soil temperature with sod cover at 10 ...           1.0  SX52
# 1109  dust, volcanic ash, blowing dust, blowing sand...           1.0  WT07
# 1112             tornado, waterspout, or funnel cloud"            1.0  WT10
# 1113                             high or damaging winds           1.0  WT11

# %%
stations_df = gather('stations',payload)
stations_df.head()
# Out:
#    elevation     mindate     maxdate  latitude  \
# 0      272.8  1963-04-01  2014-01-01  44.99070
# 1      437.7  1921-07-01  1990-10-01  47.73333
# 2      186.5  1931-01-01  2015-11-01  47.75180
# 3      411.5  1931-01-01  2015-11-01  43.70470
# 4      222.5  1950-07-01  2015-11-01  47.97110
#
#                                   name  datacoverage           id  \
# 0                 GOLDEN VALLEY, MN US        0.0225  COOP:213202
# 1                   GONVICK 2 W, MN US        0.8834  COOP:213206
# 2                  GRAND MARAIS, MN US        0.9814  COOP:213282
# 3                  GRAND MEADOW, MN US        0.9932  COOP:213290
# 4  GRAND PORTAGE RANGER STATION, MN US        0.6586  COOP:213296
#
#   elevationUnit  longitude
# 0        METERS  -93.39890
# 1        METERS  -95.51667
# 2        METERS  -90.32820
# 3        METERS  -92.56440
# 4        METERS  -89.69080

# %%
stations = stations_df.set_index('id').drop_duplicates()
stations
# Out:
#              elevation     mindate     maxdate  latitude  \
# id
# COOP:213202      272.8  1963-04-01  2014-01-01  44.99070
# COOP:213206      437.7  1921-07-01  1990-10-01  47.73333
# COOP:213282      186.5  1931-01-01  2015-11-01  47.75180
# COOP:213290      411.5  1931-01-01  2015-11-01  43.70470
# COOP:213296      222.5  1950-07-01  2015-11-01  47.97110
# ...                ...         ...         ...       ...
# WBAN:94992       185.9  2005-01-01  2020-01-09  47.74722
# WBAN:94994       204.8  2005-01-01  2020-01-09  43.15611
# WBAN:94997       417.6  2005-01-01  2020-01-09  46.44667
# WBAN:94998       393.8  2005-01-01  2020-01-09  41.70000
# WBAN:94999       367.0  2005-01-01  2020-01-09  46.54750
#
#                                             name  datacoverage elevationUnit  \
# id
# COOP:213202                 GOLDEN VALLEY, MN US        0.0225        METERS
# COOP:213206                   GONVICK 2 W, MN US        0.8834        METERS
# COOP:213282                  GRAND MARAIS, MN US        0.9814        METERS
# COOP:213290                  GRAND MEADOW, MN US        0.9932        METERS
# COOP:213296  GRAND PORTAGE RANGER STATION, MN US        0.6586        METERS
# ...                                          ...           ...           ...
# WBAN:94992                   GRAND MARAIS, MN US        1.0000        METERS
# WBAN:94994               BOSCOBEL AIRPORT, WI US        1.0000        METERS
# WBAN:94997       WADENA MUNICIPAL AIRPORT, MN US        1.0000        METERS
# WBAN:94998      AUDUBON MUNICIPAL AIRPORT, IA US        1.0000        METERS
# WBAN:94999       AITKIN MUNICIPAL AIRPORT, MN US        1.0000        METERS
#
#              longitude
# id
# COOP:213202  -93.39890
# COOP:213206  -95.51667
# COOP:213282  -90.32820
# COOP:213290  -92.56440
# COOP:213296  -89.69080
# ...                ...
# WBAN:94992   -90.34444
# WBAN:94994   -90.67750
# WBAN:94997   -95.21167
# WBAN:94998   -94.91667
# WBAN:94999   -93.67667
#
# [5344 rows x 8 columns]

# %%
stations_df['name'].value_counts()
# Out:
# NETT LAKE, MN US                    9
# MANKATO, MN US                      9
# FONTANA, WI US                      6
# MENOMONIE, WI US                    6
# HILLSBORO, WI US                    6
#                                    ..
# GREENVILLE 2 N, MI US               1
# INVER GROVE HEIGHTS 2.1 N, MN US    1
# RIVER FALLS 9.2 E, WI US            1
# EAGLE 3.4 SW, WI US                 1
# FIFE LAKE 2 WNW, MI US              1
# Name: name, Length: 4579, dtype: int64

# %%
mn_s = stations_df[stations_df['name'].str.endswith('MN US') 
                   & stations_df['id'].str.startswith('GHCND') 
                   & stations_df['maxdate'].str.startswith('2020')]

# %%
stations_df[stations_df['id'].str.endswith('WBAN:94992')]
# Out:
#       elevation     mindate     maxdate  latitude                 name  \
# 6340      185.9  2005-01-01  2020-01-09  47.74722  GRAND MARAIS, MN US
#
# GHCND:US1MISC0007               PORT HURON 2.0 SSW, MI US        0.9268
# GHCND:US1MITS0005                 FAIRGROVE 3.1 NW, MI US        0.5876
# GHCND:US1MIWY0006                   DEARBORN 1.6 W, MI US        1.0000
# GHCND:US1MIWY0123                FLAT ROCK 0.7 NNW, MI US        0.6861
# GHCND:US1MIWY0129                FLAT ROCK 2.1 NNW, MI US        0.5716
# GHCND:US1WIBN0010                GREEN BAY 5.3 SSW, WI US        1.0000
# GHCND:US1WIMC0002               TWO RIVERS 4.5 WNW, WI US        1.0000
# GHCND:USC00130608              BELLEVUE L AND D 12, IA US        1.0000
# GHCND:USC00200361                      AUBURN 2 NE, MI US        1.0000
# GHCND:USC00200981                       BRIDGEPORT, MI US        0.4997
# GHCND:USC00202015                         DEARBORN, MI US        1.0000
# GHCND:USC00202016                DEARBORN NUMBER 2, MI US        1.0000
# GHCND:USC00202170                       DOLLAR BAY, MI US        1.0000
# GHCND:USC00203178       GLEN ARBOR LEELANAU SCHOOL, MI US        0.9997
# GHCND:USC00203295     GRAND HAVEN WASTEWATER PLANT, MI US        1.0000
# GHCND:USC00206662                 PORT AUSTIN WWTP, MI US        1.0000
# WBAN:00464         J DOUGLAS BAKE MEMORIAL AIRPORT, WI US        1.0000
#
#                   elevationUnit  longitude
# id
# GHCND:US1MIBN0001        METERS -86.751916
# GHCND:US1MIBY0006        METERS -83.929367
# GHCND:US1MICP0011        METERS -84.270003
# GHCND:US1MIMB0003        METERS -82.982202
# GHCND:US1MIMB0010        METERS -82.988245
# GHCND:US1MIMB0017        METERS -82.941585
# GHCND:US1MIMB0023        METERS -82.917344
# GHCND:US1MIMB0054        METERS -82.965289
# GHCND:US1MIMG0001        METERS -86.296977
# GHCND:US1MIMG0010        METERS -86.271083
# GHCND:US1MIOW0045        METERS -86.199280
# GHCND:US1MIPI0001        METERS -83.810600
# GHCND:US1MISC0007        METERS -82.450284
# GHCND:US1MITS0005        METERS -83.582280
# GHCND:US1MIWY0006        METERS -83.245000
# GHCND:US1MIWY0123        METERS -83.279300
# GHCND:US1MIWY0129        METERS -83.287224
# GHCND:US1WIBN0010        METERS -88.030640
# GHCND:US1WIMC0002        METERS -87.667694
# GHCND:USC00130608        METERS -90.423100
# GHCND:USC00200361        METERS -84.018800
# GHCND:USC00200981        METERS -83.881670
# GHCND:USC00202015        METERS -83.237700
# GHCND:USC00202016        METERS -83.173600
# GHCND:USC00202170        METERS -88.513700
# GHCND:USC00203178        METERS -85.966670
# GHCND:USC00203295        METERS -86.204700
# GHCND:USC00206662        METERS -82.970200
# WBAN:00464               METERS -87.909770

# %%
stations_df[stations_df['id'].str.endswith('94992')]
# Out:
#       elevation     mindate     maxdate  latitude                 name  \
# 6016      185.9  1998-08-01  2020-01-07  47.74722  GRAND MARAIS, MN US
# 6340      185.9  2005-01-01  2020-01-09  47.74722  GRAND MARAIS, MN US
#
#       datacoverage                 id elevationUnit  longitude
# 6016           1.0  GHCND:USW00094992        METERS  -90.34444
# 6340           1.0         WBAN:94992        METERS  -90.34444

# %%
v_df = pd.DataFrame()
for q in query_list:
    e_df = dt_df[dt_df['name'].str.contains(q)]
    for a in avoid_list:
        e_df = e_df[~(e_df['name'].str.contains(a))]
    v_df = v_df.append(e_df)
v_df.reset_index().sort_values('datacoverage',ascending=False)
# Out:
#     index     mindate     maxdate  \
