# %%
import pandas as pd
import os
import requests
import datetime as dt
from config import noaa_token as token

# %%
#variables
base = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/'
header = {'token':token,
          'Content-Type':'application/json'}

dataset = {'datasetid':'GHCND'}
location = {'locationid':'CLIM:102'}
datatypes = {'datatypeid':'ID'}

payload = {'locationid':'CLIM:102',
          'limit':'1000'}

query_list = ['precipitation','snow','ice','water']
avoid_list = ['average','percentile','probability','multiday','mean']

# %%
#get count
def get_c(json):
    return json['metadata']['resultset']['count']

#take end point as a string and payload as a dictionary
def gather(endpt,load):
    initial = requests.get(base+endpt,headers=header,params=load).json()
    count = get_c(initial)
    json = initial['results']
    offset = 1000
    while offset < count:
        load['offset'] = offset
        json += requests.get(base+endpt,headers=header,params=load).json()['results']
        offset += 1000
    return pd.DataFrame(json)

#returns subset of df where maxdate is in December 2019
def recent(df):
    return df[df['maxdate'].str.startswith('2019-12')]

# %%
dt_df = gather('datatypes',payload)
dt_df['name'] = dt_df['name'].str.lower()
dt_df

# %%
recent(dt_df)

# %%
stations_df = gather('stations',payload)
stations_df.head()
# Out:
#    elevation     mindate     maxdate  latitude  \
# 0      272.8  1963-04-01  2014-01-01  44.99070
# 1      437.7  1921-07-01  1990-10-01  47.73333
# 2      186.5  1931-01-01  2015-11-01  47.75180
# 3      411.5  1931-01-01  2015-11-01  43.70470
# 4      222.5  1950-07-01  2015-11-01  47.97110
#
#                                   name  datacoverage           id  \
# 0                 GOLDEN VALLEY, MN US        0.0225  COOP:213202
# 1                   GONVICK 2 W, MN US        0.8834  COOP:213206
# 2                  GRAND MARAIS, MN US        0.9814  COOP:213282
# 3                  GRAND MEADOW, MN US        0.9932  COOP:213290
# 4  GRAND PORTAGE RANGER STATION, MN US        0.6586  COOP:213296
#
#   elevationUnit  longitude
# 0        METERS  -93.39890
# 1        METERS  -95.51667
# 2        METERS  -90.32820
# 3        METERS  -92.56440
# 4        METERS  -89.69080

# %%
stations_unique = stations_df['name'].unique()
stations_df[stations_df['id'] in stations_unique]
# Out:
# <ipython-input-7-9bbe4bfc36db>:2: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   stations_df[stations_df['id'] in stations_unique]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-9bbe4bfc36db> in <module>
#       1 stations_unique = stations_df['name'].unique()
# ----> 2 stations_df[stations_df['id'] in stations_unique]
#
# ~/.local/share/virtualenvs/SMMBBGKJ-TTH-Prj1-a2ue4jaD/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1205             # as it will broadcast
#    1206             if other.ndim != 0 and len(self) != len(other):
# -> 1207                 raise ValueError("Lengths must match to compare")
#    1208
#    1209             res_values = na_op(self.values, np.asarray(other))
#
# ValueError: Lengths must match to compare

# %%
stations = stations_df.set_index('id').drop_duplicates()
stations
# Out:
#              elevation     mindate     maxdate  latitude  \
# id
# COOP:213202      272.8  1963-04-01  2014-01-01  44.99070
# COOP:213206      437.7  1921-07-01  1990-10-01  47.73333
# COOP:213282      186.5  1931-01-01  2015-11-01  47.75180
# COOP:213290      411.5  1931-01-01  2015-11-01  43.70470
# COOP:213296      222.5  1950-07-01  2015-11-01  47.97110
# ...                ...         ...         ...       ...
# WBAN:94992       185.9  2005-01-01  2020-01-07  47.74722
# WBAN:94994       204.8  2005-01-01  2020-01-07  43.15611
# WBAN:94997       417.6  2005-01-01  2020-01-07  46.44667
# WBAN:94998       393.8  2005-01-01  2020-01-07  41.70000
# WBAN:94999       367.0  2005-01-01  2020-01-07  46.54750
#
#                                             name  datacoverage elevationUnit  \
# id
# COOP:213202                 GOLDEN VALLEY, MN US        0.0225        METERS
# COOP:213206                   GONVICK 2 W, MN US        0.8834        METERS
# COOP:213282                  GRAND MARAIS, MN US        0.9814        METERS
# COOP:213290                  GRAND MEADOW, MN US        0.9932        METERS
# COOP:213296  GRAND PORTAGE RANGER STATION, MN US        0.6586        METERS
# ...                                          ...           ...           ...
# WBAN:94992                   GRAND MARAIS, MN US        1.0000        METERS
# WBAN:94994               BOSCOBEL AIRPORT, WI US        1.0000        METERS
# WBAN:94997       WADENA MUNICIPAL AIRPORT, MN US        1.0000        METERS
# WBAN:94998      AUDUBON MUNICIPAL AIRPORT, IA US        1.0000        METERS
# WBAN:94999       AITKIN MUNICIPAL AIRPORT, MN US        1.0000        METERS
#
#              longitude
# id
# COOP:213202  -93.39890
# COOP:213206  -95.51667
# COOP:213282  -90.32820
# COOP:213290  -92.56440
# COOP:213296  -89.69080
# ...                ...
# WBAN:94992   -90.34444
# WBAN:94994   -90.67750
# WBAN:94997   -95.21167
# WBAN:94998   -94.91667
# WBAN:94999   -93.67667
#
# [5344 rows x 8 columns]

# %%
stations_df['name'].value_counts()

# %%
mn_s = stations_df[stations_df['name'].str.endswith('MN US') 
                   & stations_df['id'].str.startswith('GHCND') 
                   & stations_df['maxdate'].str.startswith('2020')]

# %%
stations_df[stations_df['id'].str.endswith('WBAN:94992')]

# %%
superior1 = stations[stations['elevation']>183]
superior2 = superior1[superior1['elevation']<185]
superior2

# %%
stations_df[stations_df['id'].str.endswith('94992')]

# %%
v_df = pd.DataFrame()
for q in query_list:
    e_df = dt_df[dt_df['name'].str.contains(q)]
    for a in avoid_list:
        e_df = e_df[~(e_df['name'].str.contains(a))]
    v_df = v_df.append(e_df)
v_df.reset_index().sort_values('datacoverage',ascending=False)

# %%
dt_df["mindate"]=pd.to_datetime(dt_df["mindate"])
dt_df
# Out:
#         mindate     maxdate  \
# 0    1994-03-19  1996-05-28
# 1    1965-01-01  2005-12-31
# 2    1994-02-01  1996-05-28
# 3    1965-01-01  2005-12-31
# 4    1991-06-05  2020-01-06
# ...         ...         ...
# 1126 1996-07-08  2005-09-09
# 1127 1996-10-21  2002-02-04
# 1128 1996-07-01  2005-12-31
# 1129 2010-01-01  2010-12-31
# 1130 2010-01-01  2010-12-31
#
#                                                    name  datacoverage  \
# 0     average cloudiness midnight to midnight from 3...          1.00
# 1     average cloudiness midnight to midnight from m...          1.00
# 2     average cloudiness sunrise to sunset from 30-s...          1.00
# 3     average cloudiness sunrise to sunset from manu...          1.00
# 4                                             base data          0.95
# ...                                                 ...           ...
# 1126      ash, dust, sand, or other blowing obstruction          1.00
# 1127                               snow or ice crystals          1.00
# 1128                                rain or snow shower          1.00
# 1129  long-term average year-to-date precipitation t...          1.00
# 1130     long-term average year-to-date snowfall totals          1.00
#
#                    id
# 0                ACMC
# 1                ACMH
# 2                ACSC
# 3                ACSH
# 4                 ALL
# ...               ...
# 1126             WV07
# 1127             WV18
# 1128             WV20
# 1129  YTD-PRCP-NORMAL
# 1130  YTD-SNOW-NORMAL
#
# [1131 rows x 5 columns]
