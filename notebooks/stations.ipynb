# %%
import pandas as pd
import os
import requests
import datetime as dt
from config import noaa_token as token

# %%
#variables
base = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/'
header = {'token':token,
          'Content-Type':'application/json'}

state_ids = {'PA':'FIPS:42',
            'OH':'FIPS:39',
            'MI':'FIPS:26',
            'IL':'FIPS:17',
            'WI':'FIPS:55',
            'MN':'FIPS:27',
            'IA':'FIPS:18',
            'NY':'FIPS:36'}

# %%
#get count
def get_c(json):
    return json['metadata']['resultset']['count']

def gather(endpt,load):
    initial = requests.get(base+endpt,headers=header,params=load).json()
    count = get_c(initial)
    json = initial['results']
    offset = 1000
    while offset < count:
        load['offset'] = offset
        json += requests.get(base+endpt,headers=header,params=load).json()['results']
        offset += 1000
    return pd.DataFrame(json)

# %%
stations = gather('stations',{'locationid':'CLIM:102','limit':'1000'})

# %%
stations[['First_ID','Last_ID']] = stations['id'].str.split(':',expand=True)
stations[['City','State Country']] = stations['name'].str.split(',',expand=True)
stations_no_dups = stations.set_index('id').drop_duplicates()
stations_no_dups
# Out:
#              elevation     mindate     maxdate  latitude  \
# id
# COOP:110203      228.6  1941-04-01  2008-06-01  42.48110
# COOP:113455      164.0  1935-07-01  2015-11-01  40.88210
# COOP:114355      167.6  1935-07-01  2015-11-01  41.42550
# COOP:114655      167.6  1931-01-01  2009-09-01  41.09944
# COOP:117391      173.1  1985-06-01  2015-11-01  41.51800
# ...                ...         ...         ...       ...
# WBAN:94992       185.9  2005-01-01  2020-01-09  47.74722
# WBAN:94994       204.8  2005-01-01  2020-01-09  43.15611
# WBAN:94997       417.6  2005-01-01  2020-01-09  46.44667
# WBAN:94998       393.8  2005-01-01  2020-01-09  41.70000
# WBAN:94999       367.0  2005-01-01  2020-01-09  46.54750
#
#                                            name  datacoverage elevationUnit  \
# id
# COOP:110203                      ANTIOCH, IL US        0.9542        METERS
# COOP:113455             GLADSTONE DAM 18, IL US        0.9741        METERS
# COOP:114355         ILLINOIS CITY DAM 16, IL US        0.9772        METERS
# COOP:114655                   KEITHSBURG, IL US        0.9598        METERS
# COOP:117391  ROCK ISLAND LOCK AND DAM 15, IL US        0.9479        METERS
# ...                                         ...           ...           ...
# WBAN:94992                  GRAND MARAIS, MN US        1.0000        METERS
# WBAN:94994              BOSCOBEL AIRPORT, WI US        1.0000        METERS
# WBAN:94997      WADENA MUNICIPAL AIRPORT, MN US        1.0000        METERS
# WBAN:94998     AUDUBON MUNICIPAL AIRPORT, IA US        1.0000        METERS
# WBAN:94999      AITKIN MUNICIPAL AIRPORT, MN US        1.0000        METERS
#
#              longitude First_ID Last_ID                         City  \
# id
# COOP:110203  -88.09940     COOP  110203                      ANTIOCH
# COOP:113455  -91.02340     COOP  113455             GLADSTONE DAM 18
# COOP:114355  -91.00940     COOP  114355         ILLINOIS CITY DAM 16
# COOP:114655  -90.93944     COOP  114655                   KEITHSBURG
# COOP:117391  -90.56470     COOP  117391  ROCK ISLAND LOCK AND DAM 15
# ...                ...      ...     ...                          ...
# WBAN:94992   -90.34444     WBAN   94992                 GRAND MARAIS
# WBAN:94994   -90.67750     WBAN   94994             BOSCOBEL AIRPORT
# WBAN:94997   -95.21167     WBAN   94997     WADENA MUNICIPAL AIRPORT
# WBAN:94998   -94.91667     WBAN   94998    AUDUBON MUNICIPAL AIRPORT
# WBAN:94999   -93.67667     WBAN   94999     AITKIN MUNICIPAL AIRPORT
#
#             State Country
# id
# COOP:110203         IL US
# COOP:113455         IL US
# COOP:114355         IL US
# COOP:114655         IL US
# COOP:117391         IL US
# ...                   ...
# WBAN:94992          MN US
# WBAN:94994          WI US
# WBAN:94997          MN US
# WBAN:94998          IA US
# WBAN:94999          MN US
#
# [6344 rows x 12 columns]

# %%
stations_no_dups['State Country'].value_counts()
# Out:
#  MI US    1825
#  MN US    1771
#  WI US    1401
#  IA US    1312
#  IL US      16
#  NE US       8
#  ND US       3
#  SD US       2
#  MO US       2
#  IN US       2
#  KS US       1
#  OH US       1
# Name: State Country, dtype: int64

# %%
coords_clim = stations_no_dups[['elevation','latitude','longitude']]
coords_clim.describe()
# Out:
#          elevation     latitude    longitude
# count  6225.000000  6344.000000  6344.000000
# mean    297.099454    44.055435   -90.308764
# std      79.517464     1.846201     3.970951
# min     106.700000    38.698890   -98.441670
# 25%     237.700000    42.633300   -93.448208
# 50%     286.500000    43.872450   -91.244850
# 75%     347.200000    45.304780   -87.068609
# max    1345.400000    49.318330   -81.860000

# %%
state_data = pd.DataFrame()
for state,id in state_ids.items():
    data = gather('stations',{'locationid':id,'limit':'1000'})
    print(len(data))
    data['State'] = state
    state_data = state_data.append(data,ignore_index=True)
# Out:
# 2031
# 1570
# 1833
# 2387
# 1431
# 1792
# 2030
# 2313

# %%
len(state_data)
# Out:
# 15387

# %%
state_data = state_data.set_index('id')
state_data
# Out:
#              elevation     mindate     maxdate  latitude  \
# id
# COOP:281211        3.7  1931-01-01  1978-06-01  40.08333
# COOP:284635       20.7  1931-01-01  2015-11-01  40.35958
# COOP:284736      121.9  1962-04-01  1970-08-01  41.25000
# COOP:301413      250.5  1939-01-01  2015-11-01  42.00250
# COOP:306779        NaN  1948-05-01  1948-12-01  41.36667
# ...                ...         ...         ...       ...
# WBAN:94745       111.9  1949-01-01  2020-01-09  41.06236
# WBAN:94761       335.0  2005-08-04  2020-01-09  42.48333
# WBAN:94789         3.4  1948-07-01  2020-01-09  40.63915
# WBAN:94790        96.9  1949-05-01  2020-01-09  43.98867
# WBAN:94794       216.7  1950-12-01  2007-01-18  43.14500
#
#                                          name  datacoverage elevationUnit  \
# id
# COOP:281211                 BURLINGTON, PA US        0.9650        METERS
# COOP:284635               LAMBERTVILLE, NJ US        0.9755        METERS
# COOP:284736                   LAYTON 2, PA US        0.9701        METERS
# COOP:301413                    CHEMUNG, NY US        0.9968        METERS
# COOP:306779         PORT JERVIS BRIDGE, PA US        0.1242           NaN
# ...                                       ...           ...           ...
# WBAN:94745      WESTCHESTER CO AIRPORT, NY US        0.9300        METERS
# WBAN:94761        ITHACA TOMPKINS CNTY, NY US        1.0000        METERS
# WBAN:94789   JFK INTERNATIONAL AIRPORT, NY US        1.0000        METERS
# WBAN:94790           WATERTOWN AIRPORT, NY US        1.0000        METERS
# WBAN:94794     UTICA ONEIDA CO AIRPORT, NY US        0.8100        METERS
#
#              longitude State
# id
# COOP:281211  -74.86667    PA
# COOP:284635  -74.94461    PA
# COOP:284736  -74.86667    PA
# COOP:301413  -76.63840    PA
# COOP:306779  -74.70000    PA
# ...                ...   ...
# WBAN:94745   -73.70463    NY
# WBAN:94761   -76.46667    NY
# WBAN:94789   -73.76401    NY
# WBAN:94790   -76.02623    NY
# WBAN:94794   -75.38389    NY
#
# [15387 rows x 9 columns]

# %%
coords_st = state_data[['elevation','latitude','longitude']]
coords_st.describe()
# Out:
#           elevation      latitude     longitude
# count  15226.000000  15387.000000  15387.000000
# mean     264.848489     42.135379    -84.610624
# std      114.839497      2.266795      6.082993
# min        0.000000     35.344720    -98.413060
# 25%      195.100000     40.432965    -88.860830
# 50%      248.700000     41.783330    -85.690869
# 75%      316.400000     43.499550    -79.183330
# max     1482.900000     49.318330    -71.137500
